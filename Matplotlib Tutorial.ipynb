# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace (0,5,11)

# %%
y= x**2

# %%
plt.plot(x,y,'g')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('This is a Plot')
# Out:
# Text(0.5, 1.0, 'This is a Plot')

# %% [markdown]
# ## Creating Multiplots on Same Canvas

# %%
#plt.subplot(nrows,n,clos,plot_number)
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.plot(y,x,'g*-')

# %% [markdown]
# ## OOP way to create Plot

# %%
# Create figure (empty Canvas)
fig = plt.figure()
# Add set of Axes to Figure
axes = fig.add_axes([0.1,0.1,0.8,0.8])# left,bottom,width,height (range 0 to 1)

# plot on that set of axes
axes.plot(x,y,'b')
axes.set_xlabel('X')
axes.set_ylabel('Y')
axes.set_title('This is a Title OOP')
# Out:
# Text(0.5, 1.0, 'This is a Title OOP')

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y,'r')

# %%
axes[0].plot(x,y,'r')
fig

# %%
fig = plt.figure(figsize=(12,3))

# %%
fig,axes = plt.subplots(nrows=1,ncols=1,figsize=(12,3))
axes.plot(x,y,'r')
axes.set_xlabel('X')
axes.set_ylabel('Y')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig.savefig('xyz.png',dpi=200)
